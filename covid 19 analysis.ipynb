# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as pt
import os

# %%
pwd
# Out:
# 'C:\\Users\\bindhu\\3D Objects'

# %%
data = pd.read_csv(r"C:\Users\bindhu\3D objects\COVID 19.csv")

# %%
data.head()
# Out:
#      #     Country,    Total    New Total.1   New.1    Total.2      New.2  \
# 0  NaN        Other    Cases  Cases  Deaths  Deaths  Recovered  Recovered
# 1  1.0  Afghanistan  129,021    NaN   5,415     NaN     76,218        NaN
# 2  2.0      Albania  132,544    NaN   2,456     NaN    130,033        NaN
# 3  3.0      Algeria  142,447    NaN   3,775     NaN     99,101        NaN
# 4  4.0      Andorra   13,991    NaN     127     NaN     13,752        NaN
#
#    Active  Serious, Tot�Cases/ Deaths/  Total.3     Tests/  Population
# 0   Cases  Critical     1M pop  1M pop    Tests     1M pop         NaN
# 1  47,388     1,124      3,241     136  639,329     16,059  39,811,455
# 2      55         3     46,108     854  822,310    286,059   2,874,614
# 3  39,571        29      3,190      85  230,861      5,171  44,649,627
# 4     112       NaN    180,786   1,641  193,595  2,501,551      77,390

# %%
data.columns
# Out:
# Index(['#', 'Country,', 'Total', 'New', 'Total.1', 'New.1', 'Total.2', 'New.2',
#        'Active', 'Serious,', 'Tot�Cases/', 'Deaths/', 'Total.3', 'Tests/',
#        'Population'],
#       dtype='object')

# %%
data.tail()
# Out:
#          #  Country,        Total      New    Total.1 New.1      Total.2  \
# 220    NaN     World  185,381,383  +20,199  4,008,981   389  169,720,398
# 221  220.0     Yemen        6,931      NaN      1,363   NaN        4,111
# 222  221.0    Zambia      167,132      NaN      2,559   NaN      147,751
# 223  222.0  Zimbabwe       57,963      NaN      1,939   NaN       41,624
# 224    NaN    Total:  185,381,383  +20,199  4,008,981   389  169,720,398
#
#        New.2      Active Serious, Tot�Cases/ Deaths/    Total.3   Tests/  \
# 220  +11,903  11,652,004   77,694     23,783   514.3        NaN      NaN
# 221      NaN       1,457       23        227      45    118,684    3,893
# 222      NaN      16,822    1,280      8,842     135  1,925,335  101,860
# 223      NaN      14,400       10      3,843     129    713,450   47,307
# 224  +11,903  11,652,004   77,694   23,782.7   514.3        NaN      NaN
#
#      Population
# 220         NaN
# 221  30,487,744
# 222  18,901,788
# 223  15,081,331
# ...

# %%
data.describe()
# Out:
#                 #
# count  222.000000
# mean   111.500000
# std     64.230055
# min      1.000000
# 25%     56.250000
# 50%    111.500000
# 75%    166.750000
# max    222.000000

# %%
data.isnull().sum()
# Out:
# #               3
# Country,        0
# Total           0
# New           213
# Total.1        13
# New.1         216
# Total.2         1
# New.2         214
# Active          1
# Serious,       76
# Tot�Cases/      2
# Deaths/        15
# Total.3        14
# Tests/         14
# Population      5
# dtype: int64

# %%
sns.relplot(X="total_cases",Y="deaths",data=data)
# Out:
# C:\Users\bindhu\anaconda3\lib\site-packages\seaborn\relational.py:608: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = ax.scatter(scout_x, scout_y, **kws)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-50-f590f55ddb00> in <module>
# ----> 1 sns.relplot(X="total_cases",Y="deaths",data=data)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.pairplot(data)

# %%
data.columns
# Out:
# Index(['#', 'Country,', 'Total', 'New', 'Total.1', 'New.1', 'Total.2', 'New.2',
#        'Active', 'Serious,', 'Tot�Cases/', 'Deaths/', 'Total.3', 'Tests/',
#        'Population'],
#       dtype='object')

# %%
sns.relplot(X='Active',Y='Total',Kind='Line',data=data)
# Out:
# C:\Users\bindhu\anaconda3\lib\site-packages\seaborn\relational.py:608: MatplotlibDeprecationWarning: Case-insensitive properties were deprecated in 3.3 and support will be removed two minor releases later
#   scout = ax.scatter(scout_x, scout_y, **kws)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-54-cca370d29589> in <module>
# ----> 1 sns.relplot(X='Active',Y='Total',Kind='Line',data=data)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-55-180e722218b0> in <module>
# ----> 1 sns.catplot()
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3839
#    3840     # Initialize the facets
# -> 3841     g = FacetGrid(**facet_kws)
#    3842
#    3843     # Draw the plot onto the facets
#
# ...

# %%
print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'COVID 19.csv', 'desktop.ini', 'Untitled Folder', 'Untitled.ipynb']

# %%
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-57-0ae0ded59538> in <module>
# ----> 1 df=pd.read_csv("data.csv")
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options)
#     608     kwds.update(kwds_defaults)
#     609
# ...

# %%
data = pd.read_csv(r"C:\Users\bindhu\3D objects\COVID 19.csv")

# %%
data
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      NaN        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021      NaN      5,415     NaN       76,218
# 2      2.0      Albania      132,544      NaN      2,456     NaN      130,033
# 3      3.0      Algeria      142,447      NaN      3,775     NaN       99,101
# 4      4.0      Andorra       13,991      NaN        127     NaN       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220    NaN        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931      NaN      1,363     NaN        4,111
# 222  221.0       Zambia      167,132      NaN      2,559     NaN      147,751
# 223  222.0     Zimbabwe       57,963      NaN      1,939     NaN       41,624
# 224    NaN       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.isnull().any()
# Out:
# #              True
# Country,      False
# Total         False
# New            True
# Total.1        True
# New.1          True
# Total.2        True
# New.2          True
# Active         True
# Serious,       True
# Tot�Cases/     True
# Deaths/        True
# Total.3        True
# Tests/         True
# Population     True
# dtype: bool

# %%
sns.heatmap(data.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %%
data
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      NaN        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021      NaN      5,415     NaN       76,218
# 2      2.0      Albania      132,544      NaN      2,456     NaN      130,033
# 3      3.0      Algeria      142,447      NaN      3,775     NaN       99,101
# 4      4.0      Andorra       13,991      NaN        127     NaN       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220    NaN        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931      NaN      1,363     NaN        4,111
# 222  221.0       Zambia      167,132      NaN      2,559     NaN      147,751
# 223  222.0     Zimbabwe       57,963      NaN      1,939     NaN       41,624
# 224    NaN       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.dropna()
# Out:
#          #  Country,      Total     New  Total.1 New.1    Total.2   New.2  \
# 24    24.0   Bolivia    448,213  +1,851   17,013    28    372,138  +1,760
# 89    89.0  Honduras    270,020  +1,020    7,149    20     93,654     174
# 130  130.0    Mexico  2,549,862  +7,989  233,958   269  2,023,270  +4,222
# 152  152.0  Pakistan    966,007  +1,517   22,469    17    909,525     877
# 166  166.0  S. Korea    162,753  +1,212    2,033     1    151,500     740
# 200  200.0  Thailand    301,172  +6,519    2,387    54    231,171  +4,148
#
#       Active Serious, Tot�Cases/ Deaths/     Total.3   Tests/   Population
# 24    59,062      200     37,876   1,438   1,881,330  158,979   11,833,793
# 89   169,217      596     26,831     710     812,037   80,691   10,063,569
# 130  292,634    4,798     19,569   1,796   7,613,594   58,431  130,301,571
# 152   34,013    1,941      4,289     100  14,861,926   65,990  225,216,442
# 166    9,220      155      3,172      40  10,766,502  209,817   51,313,866
# ...

# %%
data.dropna(how='all')
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      NaN        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021      NaN      5,415     NaN       76,218
# 2      2.0      Albania      132,544      NaN      2,456     NaN      130,033
# 3      3.0      Algeria      142,447      NaN      3,775     NaN       99,101
# 4      4.0      Andorra       13,991      NaN        127     NaN       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220    NaN        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931      NaN      1,363     NaN        4,111
# 222  221.0       Zambia      167,132      NaN      2,559     NaN      147,751
# 223  222.0     Zimbabwe       57,963      NaN      1,939     NaN       41,624
# 224    NaN       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.fillna(0)
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      0.0        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021        0      5,415       0       76,218
# 2      2.0      Albania      132,544        0      2,456       0      130,033
# 3      3.0      Algeria      142,447        0      3,775       0       99,101
# 4      4.0      Andorra       13,991        0        127       0       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220    0.0        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931        0      1,363       0        4,111
# 222  221.0       Zambia      167,132        0      2,559       0      147,751
# 223  222.0     Zimbabwe       57,963        0      1,939       0       41,624
# 224    0.0       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.fillna(method='bfill')
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      1.0        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021       29      5,415      28       76,218
# 2      2.0      Albania      132,544       29      2,456      28      130,033
# 3      3.0      Algeria      142,447       29      3,775      28       99,101
# 4      4.0      Andorra       13,991       29        127      28       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220  220.0        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931  +20,199      1,363     389        4,111
# 222  221.0       Zambia      167,132  +20,199      2,559     389      147,751
# 223  222.0     Zimbabwe       57,963  +20,199      1,939     389       41,624
# 224    NaN       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.interpolate()
# Out:
#          #     Country,        Total      New    Total.1   New.1      Total.2  \
# 0      NaN        Other        Cases    Cases     Deaths  Deaths    Recovered
# 1      1.0  Afghanistan      129,021      NaN      5,415     NaN       76,218
# 2      2.0      Albania      132,544      NaN      2,456     NaN      130,033
# 3      3.0      Algeria      142,447      NaN      3,775     NaN       99,101
# 4      4.0      Andorra       13,991      NaN        127     NaN       13,752
# ..     ...          ...          ...      ...        ...     ...          ...
# 220  219.5        World  185,381,383  +20,199  4,008,981     389  169,720,398
# 221  220.0        Yemen        6,931      NaN      1,363     NaN        4,111
# 222  221.0       Zambia      167,132      NaN      2,559     NaN      147,751
# 223  222.0     Zimbabwe       57,963      NaN      1,939     NaN       41,624
# 224  222.0       Total:  185,381,383  +20,199  4,008,981     389  169,720,398
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225 entries, 0 to 224
# Data columns (total 15 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   #           222 non-null    float64
#  1   Country,    225 non-null    object
#  2   Total       225 non-null    object
#  3   New         12 non-null     object
#  4   Total.1     212 non-null    object
#  5   New.1       9 non-null      object
#  6   Total.2     224 non-null    object
#  7   New.2       11 non-null     object
#  8   Active      224 non-null    object
#  9   Serious,    149 non-null    object
#  10  Tot�Cases/  223 non-null    object
#  11  Deaths/     210 non-null    object
#  12  Total.3     211 non-null    object
#  13  Tests/      211 non-null    object
#  14  Population  220 non-null    object
# dtypes: float64(1), object(14)
# memory usage: 26.5+ KB
